# %% [markdown]
# <a href="https://colab.research.google.com/github/hsiehwann/food-detection/blob/main/Yolov5v_food_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Mar  2 12:18:37 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8    30W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !curl -L "https://app.roboflow.com/ds/4EIvP5wFwr?key=toAtypGLTW" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip  #download dataset from roboflow

# %%
# %cd /content/drive/MyDrive/colab
# Out:
# /content/drive/MyDrive/colab

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/colab'

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !pip install -qr https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt

# %%
# !python yolov5/train.py --data data.yaml --cfg yolov5/models/yolov5s.yaml --weights 'yolov5/runs/train/exp6/weights/best.pt' --batch-size 64 --epochs 300 --cache  #start training
# Out:
# train: weights=yolov5/runs/train/exp6/weights/best.pt, cfg=yolov5/models/yolov5s.yaml, data=data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 4 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-7-gb2adc7c torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !python yolov5/detect.py --weights yolov5/runs/train/exp7/weights/best.pt --img 416 --conf 0.3 --source "測試" # detect food
# Out:
# detect: weights=['yolov5/runs/train/exp7/weights/best.pt'], source=測試, data=yolov5/data/coco128.yaml, imgsz=[416, 416], conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-7-gb2adc7c torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7061368 parameters, 0 gradients
# image 1/22 /content/drive/MyDrive/colab/測試/PXL_20220221_120037863.jpg: 416x320 2 豬耳朵s, 2 鴨胗s, Done. (0.024s)
# image 2/22 /content/drive/MyDrive/colab/測試/PXL_20220221_120044245.jpg: 416x320 1 豬耳朵, 1 玉米筍, 5 鴨胗s, Done. (0.025s)
# image 3/22 /content/drive/MyDrive/colab/測試/PXL_20220221_120049621.jpg: 416x320 1 豬耳朵, Done. (0.024s)
# ...

# %%
# !python export.py --weights runs/train/exp/weights/best.pt --data /data.yaml --include tflite
